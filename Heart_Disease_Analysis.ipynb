# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# total data columns
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
#  check null values
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#  summary or dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# quick overview here 
df.hist(bins=50, grid=False, figsize=(20,15));

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# # data analysis

# %%
# How many people are affected by heart disease, and how many are not
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df.target.value_counts().plot(kind='bar', color=['red' ,'blue'])
# title
plt.title("Heart disease value")
plt.xlabel('1 = affected people,    0 = not affected people')
plt.ylabel('total counts')
# Out:
# Text(0, 0.5, 'total counts')

# %%
#plotting a pie chart
df.target.value_counts().plot(kind = 'pie', figsize = (7,7))
plt.legend(["affected people" , "not affected people"])

# %%
# Which gender tends to have the highest occurrence of heart disease?
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
#plotting a pie chart
df.target.value_counts().plot(kind = 'pie', figsize = (7,7))
plt.legend(["Male" , "Female"])

# %%
pd.crosstab(df.sex,df.target)
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
sns.countplot(x= 'target' , data = df, hue = "sex")
plt.title('gender tends of heart disease')
# Out:
# Text(0.5, 1.0, 'gender tends of heart disease')

# %%
# Among different genders, which experiences a particular type of chest pain more frequently
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
df.cp.value_counts().plot(kind="bar", color= ['springgreen', 'blue','salmon','red'])
plt.title("Experiences a particular type of chest pain ")
plt.xlabel(' chest pain')
plt.ylabel(' value')
# Out:
# Text(0, 0.5, ' value')

# %%
pd.crosstab(df.sex,df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex, df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
# sex and chest pain
pd.crosstab(df.sex, df.cp).plot(kind = 'bar', color = ['springgreen', 'blue','salmon','red'])
plt.title('Type of chest pain for sex')
plt.xlabel('0 = Female,    1 = Male');

# %%
# Which type of chest pain indicates a higher likelihood of heart disease

# %%
pd.crosstab(df.cp, df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x = "cp", data = df, hue= 'target')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
# How does age correlate with maximum heart rate in individuals with heart disease
# How does age correlate with maximum heart rate in individuals without heart disease

# %%
#create a distribution plot with normal distribution curve
sns.displot( x = 'age', data = df, bins = 30, kde = True);
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure()

plt.scatter(df.age[df.target == 1],
           df.thalach[df.target == 1])
#  add title
plt.title("max heart rate vs age")
plt.xlabel('Age')
plt.ylabel('hraet rate')
# Out:
# Text(0, 0.5, 'hraet rate')

# %%
df.age[df.target ==1]
# Out:
# 5       58
# 10      71
# 12      34
# 15      34
# 16      51
#         ..
# 1011    45
# 1014    44
# 1019    47
# 1020    59
# 1023    50
# Name: age, Length: 526, dtype: int64

# %%
# Creating a figure
plt.figure()

#plotting the values for people who have heart disease
plt.scatter(df.age[df.target==1], 
            df.thalach[df.target==1], 
            c="springgreen") # color

#plotting the values for people who doesn't have heart disease
plt.scatter(df.age[df.target==0], 
            df.thalach[df.target==0])

# Addind info
plt.title("Heart Disease w.r.t Age and Max Heart Rate")
plt.xlabel("Age")
plt.legend(["Disease", "No Disease"])
plt.ylabel(" Heart Rate")
# Out:
# Text(0, 0.5, ' Heart Rate')

# %%
# Creating a figure
plt.figure()

#plotting the values for people who have heart disease
plt.scatter(df.age[df.target==1], 
            df.chol[df.target==1], 
            c="salmon") # color

#plotting the values for people who doesn't have heart disease
plt.scatter(df.age[df.target==0], 
            df.chol[df.target==0])

# Addind info
plt.title("serum Cholestroral vs Age")
plt.xlabel("Age")
plt.legend(["Disease", "No Disease"])
plt.ylabel("serum Cholestroral")
# Out:
# Text(0, 0.5, 'serum Cholestroral')

# %%
sns.kdeplot(x = 'age', y = 'thalach', data = df, color = 'darkcyan')
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
# What's the relationship between age and serum cholesterol levels in people with heart disease

# %%
sns.displot(x = df.thalach[df.target==1], data = df, kde = True, color= 'olive')
plt.title("Maximum heart achieved of peple with heart disease")
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Number of people with heart disease")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(13.819444444444445, 0.5, 'Number of people with heart disease')

# %%
sns.displot(x = df.thalach[df.target==0], data = df, kde = True, color= 'slategray')
plt.title("Maximum heart achieved of people without heart disease")
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Number of people without heart disease")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(13.819444444444445, 0.5, 'Number of people without heart disease')

# %%
sns.displot(x = 'chol', data = df, bins = 30, kde = True, color = 'teal')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Creating another figure
plt.figure(figsize=(10,6))

#plotting the values for people who have heart disease
plt.scatter(df.age[df.target==1], 
            df.chol[df.target==1], 
            c="salmon") # define it as a scatter figure

#plotting the values for people who doesn't have heart disease
plt.scatter(df.age[df.target==0], 
            df.chol[df.target==0], 
            c="lightblue") # axis always come as (x, y)

# Add some helpful info
plt.title("Heart Disease w.r.t Age and Serum Cholestoral")
plt.xlabel("Age")
plt.legend(["Disease", "No Disease"])
plt.ylabel("Serum cholestoral")
# Out:
# Text(0, 0.5, 'Serum cholestoral')

# %%
sns.kdeplot(x = 'age', y = 'chol', data = df, color = 'firebrick')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.displot(x = df.chol[df.target==1], data = df, kde = True, color= 'dodgerblue')
plt.title("Serum Cholestoralof people with heart disease")
plt.xlabel("Serum Cholestoral")
plt.ylabel("Number of people with heart disease")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(13.819444444444445, 0.5, 'Number of people with heart disease')

# %%
sns.displot(x = df.chol[df.target==0], data = df, kde = True, color= 'forestgreen')
plt.title("Serum Cholestoralof people without heart disease")
plt.xlabel("Serum Cholestoral")
plt.ylabel("Number of people without heart disease")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(13.819444444444445, 0.5, 'Number of people without heart disease')

# %%
sns.countplot(x = 'exang', data = df, hue = 'sex')
plt.title('Exercise induced angina for sex')
plt.xlabel('exercise induced angina')
# Out:
# Text(0.5, 0, 'exercise induced angina')

# %%
# Which gender tends to have a higher occurrence of fasting blood sugar levels exceeding 120 mg/dl
df.fbs.value_counts()
# Out:
# fbs
# 0    872
# 1    153
# Name: count, dtype: int64

# %%
df.fbs.value_counts().plot(kind = 'pie', figsize = (8, 6))
plt.legend(['fbs<120 mg/dl', 'fbs>120 mg/dl'])

# %%
pd.crosstab(df.sex, df.fbs)
# Out:
# fbs    0    1
# sex
# 0    270   42
# 1    602  111

# %%
pd.crosstab(df.sex, df.fbs).plot(kind = 'bar', color = ['lightblue', 'salmon'])
plt.title("Fasting blood sugar w.r.t sex")
plt.xlabel("0 = Female,   1 = Male")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
